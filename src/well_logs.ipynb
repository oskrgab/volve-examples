# %%
from welly import Well, Project

# %%
project = Project.from_las("data/well_logs/interpretation/*.las")
project
# Out:
# 1it [00:00,  6.98it/s]Only engine='normal' can read wrapped files
# 3it [00:00,  6.72it/s]
# Project(3 wells: , , )

# %%
project[0].plot()
